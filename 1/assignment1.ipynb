# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("autodata.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
# 5           5          2                122         audi        std
# 6           6          1                158         audi        std
# 7           7          1                122         audi        std
# 8           8          1                158         audi      turbo
# 9           9          2                192          bmw        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'diesel', 'gas'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df['stroke'].head()
# Out:
# 0    2.68
# 1    2.68
# 2    3.47
# 3    3.40
# 4    3.40
# Name: stroke, dtype: float64

# %%
modeStroke = df['stroke'].mode().astype('float').iloc[0]

# %%
df['stroke']=df['stroke'].fillna(modeStroke)
df['stroke'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['horsepower'].head(5)
# Out:
# 0    111.0
# 1    111.0
# 2    154.0
# 3    102.0
# 4    115.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())
df['horsepower'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['peak-rpm'].head(15)
# Out:
# 0     5000.0
# 1     5000.0
# 2     5000.0
# 3     5500.0
# 4     5500.0
# 5     5500.0
# 6     5500.0
# 7     5500.0
# 8     5500.0
# 9     5800.0
# 10    5800.0
# 11    4250.0
# 12    4250.0
# 13    4250.0
# 14    5400.0
# Name: peak-rpm, dtype: float64

# %%
bins = np.linspace(df['peak-rpm'].min(),df['peak-rpm'].max(),4)
groups = ['low', 'mid', 'high']
df['binnedPeakRPM'] = pd.cut(df['peak-rpm'],bins=bins, labels = groups, include_lowest = True)
df[['binnedPeakRPM','peak-rpm']].head(20)
# Out:
#    binnedPeakRPM  peak-rpm
# 0            mid    5000.0
# 1            mid    5000.0
# 2            mid    5000.0
# 3            mid    5500.0
# 4            mid    5500.0
# 5            mid    5500.0
# 6            mid    5500.0
# 7            mid    5500.0
# 8            mid    5500.0
# 9           high    5800.0
# 10          high    5800.0
# 11           low    4250.0
# 12           low    4250.0
# 13           low    4250.0
# 14           mid    5400.0
# 15           mid    5400.0
# 16           mid    5400.0
# 17           mid    5100.0
# 18           mid    5400.0
# 19           mid    5400.0

# %%
df['city-L/100km'] =235/df['city-mpg']

# %%
df[['city-L/100km','city-mpg']].head(20)
# Out:
#     city-L/100km  city-mpg
# 0      11.190476        21
# 1      11.190476        21
# 2      12.368421        19
# 3       9.791667        24
# 4      13.055556        18
# 5      12.368421        19
# 6      12.368421        19
# 7      12.368421        19
# 8      13.823529        17
# 9      10.217391        23
# 10     10.217391        23
# 11     11.190476        21
# 12     11.190476        21
# 13     11.750000        20
# 14     14.687500        16
# 15     14.687500        16
# 16     15.666667        15
# 17      5.000000        47
# 18      6.184211        38
# 19      6.184211        38

# %%
df['length'] = 10*df['length']

# %%
df['length'].head()
# Out:
# 0    8.111485
# 1    8.111485
# 2    8.226814
# 3    8.486305
# 4    8.486305
# Name: length, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['scaled-lenght'] = scaler.fit_transform(df[['length']])
df[['scaled-lenght','length']].head()
# Out:
#    scaled-lenght    length
# 0       0.413433  8.111485
# 1       0.413433  8.111485
# 2       0.449254  8.226814
# 3       0.529851  8.486305
# 4       0.529851  8.486305

# %%
df['width'] = 10*df['width']
df['width'].head()
# Out:
# 0    8.902778
# 1    8.902778
# 2    9.097222
# 3    9.194444
# 4    9.222222
# Name: width, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['scaled-width'] = scaler.fit_transform(df[['width']])
df[['scaled-width','width']].head()
# Out:
#    scaled-width     width
# 0     -0.853460  8.902778
# 1     -0.853460  8.902778
# 2     -0.185597  9.097222
# 3      0.148335  9.194444
# 4      0.243744  9.222222

# %%
df['transformedPrice'] = np.log(df['price']+1)
df[['transformedPrice','price']].head(10)
# Out:
#    transformedPrice    price
# 0          9.510149  13495.0
# 1          9.711176  16500.0
# 2          9.711176  16500.0
# 3          9.543306  13950.0
# 4          9.767152  17450.0
# 5          9.632400  15250.0
# 6          9.781941  17710.0
# 7          9.848028  18920.0
# 8         10.080629  23875.0
# 9          9.706925  16430.0

# %%
plt.hist(df['transformedPrice'], bins=20, alpha=0.499, label='Transformed Price (Log)')
plt.legend()
plt.title('Histogram: Transformed Price')
plt.show()
plt.xscale('log')
plt.hist(df['price'], bins=10, alpha=0.7, label='Original Price')
plt.hist(df['transformedPrice'], bins=20, alpha=0.7, label='Transformed Price (Log)')
plt.legend()
plt.title('Histogram: Original vs. Transformed Price')
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'diesel', 'gas', 'binnedPeakRPM',
#        'city-L/100km', 'scaled-lenght', 'scaled-width', 'transformedPrice'],
#       dtype='object')

# %%
df['numericalCategoricalRPM']=df['binnedPeakRPM'].replace({'high':2,'mid':1,'low':0})
df[['binnedPeakRPM','numericalCategoricalRPM']].head(25)
# Out:
# C:\Users\gunsm\AppData\Local\Temp\ipykernel_31032\3070403726.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['numericalCategoricalRPM']=df['binnedPeakRPM'].replace({'high':2,'mid':1,'low':0})
# C:\Users\gunsm\AppData\Local\Temp\ipykernel_31032\3070403726.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['numericalCategoricalRPM']=df['binnedPeakRPM'].replace({'high':2,'mid':1,'low':0})
#    binnedPeakRPM numericalCategoricalRPM
# 0            mid                       1
# 1            mid                       1
# ...
