# %%
import pandas as pd

# %%
df = pd.read_csv('HousingData.csv')

# %%
df =df.dropna()
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x = df.drop('MEDV',axis=1)
y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0,test_size=0.20)

# %%
x_train
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 275   0.09604   40.0   6.41   0.0  0.447  6.854   42.8  4.2673    4  254
# 180   0.06588    0.0   2.46   0.0  0.488  7.765   83.3  2.7410    3  193
# 327   0.24103    0.0   7.38   0.0  0.493  6.083   43.7  5.4159    5  287
# 424   8.79212    0.0  18.10   0.0  0.584  5.565   70.6  2.0635   24  666
# 500   0.22438    0.0   9.69   0.0  0.585  6.027   79.7  2.4982    6  391
# ..        ...    ...    ...   ...    ...    ...    ...     ...  ...  ...
# 415  18.08460    0.0  18.10   0.0  0.679  6.434  100.0  1.8347   24  666
# 248   0.16439   22.0   5.86   0.0  0.431  6.433   49.1  7.8265    7  330
# 141   1.62864    0.0  21.89   0.0  0.624  5.019  100.0  1.4394    4  437
# 57    0.01432  100.0   1.32   0.0  0.411  6.816   40.5  8.3248    5  256
# 218   0.11069    0.0  13.89   1.0  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT
# 275     17.6  396.90   2.98
# 180     17.8  395.56   7.56
# 327     19.6  396.90  12.79
# 424     20.2    3.65  17.16
# 500     19.2  396.90  14.33
# ..       ...     ...    ...
# 415     20.2   27.25  29.05
# 248     19.1  374.71   9.52
# 141     21.2  396.90  34.41
# 57      15.1  392.90   3.95
# 218     16.4  396.90  17.92
#
# [315 rows x 13 columns]

# %%
x_train.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-7.16684077e-02,  4.07806194e-02,  6.50846492e-02,  2.71199389e+00,
#        -1.97944606e+01,  5.25326355e+00, -2.41978326e-02, -1.47008905e+00,
#         2.41939668e-01, -1.38321132e-02, -8.96696071e-01,  1.03939063e-02,
#        -3.19933717e-01])

# %%
regressor.intercept_
# Out:
# np.float64(26.643103405315717)

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred.shape
# Out:
# (79,)

# %%
result = pd.DataFrame({'Actual': y_test, 'Prediction':y_pred})

# %%
result
# Out:
#      Actual  Prediction
# 136    17.4   16.191600
# 360    25.0   19.914843
# 81     23.9   26.517535
# 195    50.0   41.548241
# 421    14.2   16.378620
# ..      ...         ...
# 106    19.5   17.378550
# 153    19.4   15.868459
# 76     20.0   23.036573
# 65     23.5   29.637718
# 385     7.2    8.760596
#
# [79 rows x 2 columns]

# %%
residual_error = abs(y_test-y_pred)

# %%
residual_error
# Out:
# 136    1.208400
# 360    5.085157
# 81     2.617535
# 195    8.451759
# 421    2.178620
#          ...
# 106    2.121450
# 153    3.531541
# 76     3.036573
# 65     6.137718
# 385    1.560596
# Name: MEDV, Length: 79, dtype: float64

# %%
meanAbsError = sum(residual_error)/len(residual_error)

# %%
meanAbsError
# Out:
# 3.4843562556302543

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
mae(y_pred,y_test)
# Out:
# 3.4843562556302543

# %%
from sklearn.metrics import r2_score 
r2_score(y_test,y_pred)
# Out:
# 0.58065631230158
